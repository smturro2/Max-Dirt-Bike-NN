# %% [markdown]
# # Imports

# %%
from web_controller import WebController
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # 1.) Start the Game
# Run the following code block

# %%
wc = WebController()

# %% [markdown]
# # 2.) Start the first level but don't move
# Also make sure your cursor is not on the screen
# # 3.) Start Recording
# Run the following code block. To stop the recording just exit the window

# %%
wc.start_record_list_base(500)
# Out:
# Recording started with run number 5180
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# C:\Users\SCOTTT~1\AppData\Local\Temp/ipykernel_5428/4007495502.py in <module>
# ----> 1 wc.start_record_list_base(500)
#
# C:\dev\Classes\Stat 430 Deep\git_Max-Dirt-Bike-NN\web_controller\web_controller.py in start_record_list_base(self, num_iters)
#     175         for i in range(num_iters):
#     176             start_time = time.time()
# --> 177             img_list.append(self.driver.get_screenshot_as_base64())
#     178             key_info += self.get_current_inputs()
#     179             times[i] = time.time() - start_time
#
# C:\Anaconda\envs\main\lib\site-packages\selenium\webdriver\remote\webdriver.py in get_screenshot_as_base64(self)
#    1072             driver.get_screenshot_as_base64()
#    1073         """
# -> 1074         return self.execute(Command.SCREENSHOT)['value']
# ...

# %%
num_plot = 1

max_x = 1
min_x = 0
for col in ["list","save","list_base","list_png"]:
    plt.figure()
    mean,std = norm.fit(df[col])
    plt.plot(df[col],np.zeros_like(df[col]),".k")
    x_vals = np.linspace(min_x,max_x,50)
    plt.plot(x_vals,norm.pdf(x_vals,mean,std),"-.r")
    plt.xlim((min_x,max_x))
    plt.title(f"col: {col}\nmean: {mean}\nstd:{std}\n avg frames/sec:{1/mean}")
    plt.show()
    num_plot+=1
